# %%
from filmoscopie import wikipedia

# %%
movies, total = wikipedia.movies_documents()
for id_, text, movie in movies:
    if movie["genre"] == []:
        print(movie)
        print(text)
# Out:
# {'title': 'Festival de Cannes 1938', 'genre': [], 'duration': 12, 'year': 1938, 'imdb': None}
# vignette|Note de 1939 avec la décision du gouvernement français de ne plus participer à la Mostra de Venise, mais d’organiser son propre festival à Biarritz, Cannes ou Nice.
# ...
